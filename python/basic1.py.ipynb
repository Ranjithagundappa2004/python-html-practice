# %%
class fan:
    def __init__(self):
        self.brand="Usha"
        self.color="white"
        self.cost=1500
        self.wings=3

    def on(self):
        print("fan is on")

    def rotate(self):
        print("fan is rotating")

    def off(self):
        print("fan is off")

f1=fan()
print(f1.brand)
print(f1.color)
print(f1.cost)
print(f1.wings)

f1.on()
f1.rotate()
f1.off()
# Out:
# Usha
# white
# 1500
# 3
# fan is on
# fan is rotating
# fan is off

# %%
class student:
    def __init__(self):
        self.name="Ranju"
        self.age=20
        self.phonenumber=9035258689

    def study(self):
        print("student is studying")

s1=student()

print(s1.name)
print(s1.age)
print(s1.phonenumber)
s1.study()
# Out:
# Ranju
# 20
# 9035258689
# student is studying

# %%
class Heroine:
    def __init__(self):
        self.name="rukku"
        self.age=20
        self.numOfMovies=3

    def act(self):
        print("Heroine is acting")

h1= Heroine()
print(h1.name)
print(h1.age)
print(h1.numOfMovies)
h1.act()
# Out:
# rukku
# 20
# 3
# Heroine is acting

# %%
class Hero:
    def __init__(self):
        self.name="yash"
        self.age=45
        self.numOfMovies=25
    def act(self):
        print("Hero is acting")

h1=Hero()
print(h1.name)
print(h1.age)
print(h1.numOfMovies)
h1.act()
h1.movie="KGF"# adding of the variablrs
print(h1.movie)
h1.age=47 #Modifying the variables  mod
print(h1.age)
del h1.numOfMovies #deleting the variable
# Out:
# yash
# 45
# 25
# Hero is acting
# KGF
# 47

# %%
class car:
    def __init__(self):
        self.brand="TATA"
        self.color="white"

    def start(self):
        print("car is starting")
        print(self.color)
        print(self)

c1=car()
print(c1.brand)
print(c1.color)
c1.start()
print(c1)
# Out:
# TATA
# white
# car is starting
# white
# ...

# %%
a=10
b=10
c=10
d=20
print(a)
print(id(a))
print(id(b))
print(id(c))
print(id(d))
# Out:
# 10
# 140703231239368
# 140703231239368
# 140703231239368
# 140703231239688

# %%
class cat:
    def __init__(self):
        self.colour="white"
        self.legs=4
        self.ears=2

    def sound(self):
        print("cat is sounding")

c1=cat()
print(c1.colour)
print(c1.legs)
print(c1.ears)
c1.sound()
# Out:
# white
# 4
# 2
# cat is sounding

# %%
class flower:
    def __init__(self):
        self.name="rose"
        self.petals=20
        self.colour="red"

    def bloom(self):
        print("flower is blooming")
        print(self.petals)
        print(self)

f1=flower()
print(f1.petals)
print(f1.name)
print(f1.colour)
f1.bloom()
print(f1)
# Out:
# 20
# rose
# red
# flower is blooming
# 20
# ...

# %%
a=10
print(a)
print(type(a))

b=20.5
print(b)
print(type(b))

c="ranju"
print(c)
print(type(c))
# Out:
# 10
# <class 'int'>
# 20.5
# <class 'float'>
# ranju
# <class 'str'>

# %%
a=input("Enter a number:")
b=input("Enter a number:")
print(a)
print(b)
# Out:
# 5
# 10

# %%
a=input("Enter a number:")
b=input("Enter a number:")
c=a+b
print(c)
# I have given the input 10 and 20
# Out:
# 1020

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
c=a+b
print(c)
# I have given the input 10 and 20
# Out:
# 30

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
if a>b:
    print("a is greater")
elif a<b:
    print("b is greater")
else:
    print("both are equal")
# Out:
# both are equal

# %%
a=int(input("Enter a number:"))
b=int(input("Enter a number:"))
if a>b:
    print("a is greater")
elif b>a:
    print("b is greater")
else:
    print("both are equal")
# Out:
# b is greater

# %%
 for i in 10,15.5,"Yuva":
     print(i)
# Out:
# 10
# 15.5
# Yuva

# %%
for i in "Rahul","Ramya":
    print(i)
# Out:
# Rahul
# Ramya

# %%
for i in "ranju":
    print(i)
# Out:
# r
# a
# n
# j
# u

# %%
for i in 1,2,3,4:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in 10:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for i in 10:
#       2     print(i)
#
# TypeError: 'int' object is not iterable
